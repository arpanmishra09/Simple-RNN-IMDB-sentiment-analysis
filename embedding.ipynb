# %%
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import Embedding,Input
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential
import numpy as np

# %%
sent=[
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good developer',
    'understand the meaning of words',
    'your videos are good'
]

# %%
# define vocab size
vocab_size=10000

# %%
#one hot representation
one_hot_repr= [one_hot(words,vocab_size) for words in sent]
one_hot_repr
# Out:
# [[9146, 8040, 5329, 5539],
#  [9146, 8040, 5329, 6730],
#  [9146, 5635, 5329, 6743],
#  [5582, 2637, 8066, 290, 2021],
#  [5582, 2637, 8066, 290, 6171],
#  [4604, 9146, 2930, 5329, 8106],
#  [8947, 4197, 2935, 290]]

# %%
## word embedding representation
sent_len=8
embeded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_len)

# %%
embeded_docs
# Out:
# array([[   0,    0,    0,    0, 9146, 8040, 5329, 5539],
#        [   0,    0,    0,    0, 9146, 8040, 5329, 6730],
#        [   0,    0,    0,    0, 9146, 5635, 5329, 6743],
#        [   0,    0,    0, 5582, 2637, 8066,  290, 2021],
#        [   0,    0,    0, 5582, 2637, 8066,  290, 6171],
#        [   0,    0,    0, 4604, 9146, 2930, 5329, 8106],
#        [   0,    0,    0,    0, 8947, 4197, 2935,  290]], dtype=int32)

# %%
## feature representation
dim=10

# %%
model = Sequential([
    Input(shape=(sent_len,)),
    Embedding(vocab_size, dim)
])
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)         │ (None, 8, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embeded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# array([[[-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.03332708, -0.01392758,  0.03073728,  0.01517676,
#          -0.00312705, -0.04459501, -0.03693111,  0.02951317,
#          -0.00838326, -0.04346534],
#         [ 0.00766836,  0.00365497,  0.04573455,  0.03513714,
#          -0.01825779,  0.03025899,  0.00913793, -0.04470491,
#          -0.00367787,  0.02418328],
#         [ 0.0139485 ,  0.0017589 , -0.04793897, -0.03578421,
#           0.00164137, -0.04134113, -0.0169095 , -0.04882593,
#          -0.02976084,  0.02442515],
#         [ 0.00176741, -0.03299971,  0.02072803, -0.01622032,
#           0.04432293,  0.02902809, -0.02387424,  0.04273931,
#          -0.00245146,  0.01299799]],
#
#        [[-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.03332708, -0.01392758,  0.03073728,  0.01517676,
#          -0.00312705, -0.04459501, -0.03693111,  0.02951317,
#          -0.00838326, -0.04346534],
#         [ 0.00766836,  0.00365497,  0.04573455,  0.03513714,
#          -0.01825779,  0.03025899,  0.00913793, -0.04470491,
#          -0.00367787,  0.02418328],
#         [ 0.0139485 ,  0.0017589 , -0.04793897, -0.03578421,
#           0.00164137, -0.04134113, -0.0169095 , -0.04882593,
#          -0.02976084,  0.02442515],
#         [ 0.01467181,  0.02674012, -0.02378794,  0.03622252,
#          -0.04943157, -0.03117093, -0.0210686 , -0.01840333,
#          -0.03181944,  0.03188665]],
#
#        [[-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.03332708, -0.01392758,  0.03073728,  0.01517676,
#          -0.00312705, -0.04459501, -0.03693111,  0.02951317,
#          -0.00838326, -0.04346534],
#         [-0.01066377, -0.0073899 ,  0.03729564, -0.0032425 ,
#           0.01642251, -0.00371283, -0.02918998,  0.048077  ,
#          -0.03790877,  0.04914409],
#         [ 0.0139485 ,  0.0017589 , -0.04793897, -0.03578421,
#           0.00164137, -0.04134113, -0.0169095 , -0.04882593,
#          -0.02976084,  0.02442515],
#         [ 0.04049617,  0.04846505, -0.00921669, -0.02163103,
#           0.02705305,  0.02838465, -0.00961982, -0.00433061,
#           0.03193214, -0.0173688 ]],
#
#        [[-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [ 0.01069771, -0.02795162,  0.04492091, -0.01126813,
#           0.00655163,  0.0078182 , -0.0024137 , -0.04010553,
#          -0.01103407,  0.00724925],
#         [ 0.04165694, -0.00847423, -0.02120063,  0.02149191,
#           0.03816397, -0.01761646,  0.0159556 ,  0.02783911,
#           0.03242923, -0.01535482],
#         [ 0.00576725,  0.01805324,  0.04768939, -0.04756049,
#          -0.01970618,  0.01715547,  0.00820971, -0.02104121,
#          -0.00623993,  0.0462363 ],
#         [-0.04452639, -0.04291144,  0.03806876,  0.01394267,
#           0.01838276, -0.01921409,  0.02550605, -0.0169601 ,
#           0.01483407, -0.04265428],
#         [ 0.04859937,  0.03691299, -0.01410283, -0.00910708,
#           0.02551632, -0.03778881,  0.02344095, -0.01095708,
#          -0.01017104, -0.0496097 ]],
#
#        [[-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [ 0.01069771, -0.02795162,  0.04492091, -0.01126813,
#           0.00655163,  0.0078182 , -0.0024137 , -0.04010553,
#          -0.01103407,  0.00724925],
#         [ 0.04165694, -0.00847423, -0.02120063,  0.02149191,
#           0.03816397, -0.01761646,  0.0159556 ,  0.02783911,
#           0.03242923, -0.01535482],
#         [ 0.00576725,  0.01805324,  0.04768939, -0.04756049,
#          -0.01970618,  0.01715547,  0.00820971, -0.02104121,
#          -0.00623993,  0.0462363 ],
#         [-0.04452639, -0.04291144,  0.03806876,  0.01394267,
#           0.01838276, -0.01921409,  0.02550605, -0.0169601 ,
#           0.01483407, -0.04265428],
#         [-0.01791785, -0.0010714 , -0.01635636,  0.0214524 ,
#          -0.03821073,  0.00209073,  0.04339397, -0.02413361,
#           0.0034874 , -0.01757845]],
#
#        [[-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.01985041, -0.04747574, -0.00039232, -0.00981509,
#           0.03585236,  0.02832008, -0.03565275, -0.03852445,
#          -0.00405399,  0.03403965],
#         [-0.03332708, -0.01392758,  0.03073728,  0.01517676,
#          -0.00312705, -0.04459501, -0.03693111,  0.02951317,
#          -0.00838326, -0.04346534],
#         [-0.01664089,  0.0112452 ,  0.02501786,  0.0380347 ,
#          -0.00249005,  0.00010012, -0.01194106,  0.00717961,
#          -0.00134425,  0.01906494],
#         [ 0.0139485 ,  0.0017589 , -0.04793897, -0.03578421,
#           0.00164137, -0.04134113, -0.0169095 , -0.04882593,
#          -0.02976084,  0.02442515],
#         [-0.02018513,  0.01250874,  0.03653238,  0.04576315,
#          -0.04351563, -0.04701604,  0.00875548, -0.04826767,
#          -0.02256414,  0.02561077]],
#
#        [[-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [-0.02302977,  0.03546223, -0.04718946,  0.04198596,
#          -0.04243766,  0.00586262, -0.00190111,  0.02454349,
#          -0.03362   , -0.01908045],
#         [ 0.02201818, -0.04242478,  0.00234501,  0.0164527 ,
#          -0.02055881,  0.04727978,  0.00914581,  0.00398811,
#           0.0336213 , -0.04788354],
#         [ 0.00023537,  0.01532135, -0.01108208, -0.04318517,
#           0.03284052,  0.03188281,  0.02596808,  0.00941472,
#           0.04103727, -0.02567921],
#         [ 0.00498216,  0.03109164, -0.02491005, -0.01067359,
#          -0.02495578, -0.03965256,  0.01678642,  0.00719143,
#          -0.03442811, -0.0128703 ],
#         [-0.04452639, -0.04291144,  0.03806876,  0.01394267,
#           0.01838276, -0.01921409,  0.02550605, -0.0169601 ,
#           0.01483407, -0.04265428]]], dtype=float32)
